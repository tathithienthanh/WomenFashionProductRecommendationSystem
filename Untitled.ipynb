# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# *Route*

# %%
# from selenium import webdriver
# from selenium.webdriver.chrome.service import Service
# from webdriver_manager.chrome import ChromeDriverManager
# import pymssql
# import pandas as pd

# # 1. Setup Selenium and Database Connection
# chrome_options = webdriver.ChromeOptions()
# chrome_options.add_argument("--headless")
# driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=chrome_options)

# conn = pymssql.connect(
#     server='your_server_name',
#     user='your_username',
#     password='your_password',
#     database='E_Market'
# )
# cursor = conn.cursor()

# # 2. Scrape Data from Website 1
# def scrape_website1():
#     driver.get('https://website1.com')
#     # Extract data
#     products = []  # Example list to store product data
#     # Scrape code here ...
#     for product in products:
#         cursor.execute('''INSERT INTO Product (name, rate, id_shop, price, detail, url) 
#                           VALUES (%s, %f, %d, %f, %s, %s)''',
#                        (product['name'], product['rate'], product['id_shop'], 
#                         product['price'], product['detail'], product['url']))
#     conn.commit()

# # Repeat similar functions for Website 2 and 3

# # 3. Process Data (Cleaning)
# def clean_data():
#     df = pd.read_sql('SELECT * FROM Product', conn)
#     # Clean data using pandas, e.g., removing duplicates
#     df.drop_duplicates(inplace=True)
#     # Update the cleaned data back into the database
#     for index, row in df.iterrows():
#         cursor.execute('''UPDATE Product SET 
#                           name=%s, rate=%f, price=%f, detail=%s, url=%s 
#                           WHERE id=%d''',
#                        (row['name'], row['rate'], row['price'], 
#                         row['detail'], row['url'], row['id']))
#     conn.commit()

# # 4. Run the entire process
# scrape_website1()
# # scrape_website2()
# # scrape_website3()

# clean_data()

# # 5. Analyze Data (Example)
# df = pd.read_sql('SELECT * FROM Product', conn)
# analysis = df.groupby('id_shop').agg({'rate': 'mean'}).reset_index()
# print(analysis)

# # 6. Close connections
# driver.quit()
# conn.close()

# %% [markdown]
# # Setup Selenium and Database Connection

# %% [markdown]
# Run this cell if the computer hasn't installed the selenium, pymssql, and webdriver-manager libraries yet

# %%
# !pip install selenium
# !pip install pymssql
# !pip install webdriver-manager

# %%
import pymssql

conn = pymssql.connect(
    server='THANH', 
    user='',
    password='',
    database='E_Market'
)
cursor = conn.cursor()

# %%
cursor.execute('''
    IF OBJECT_ID('User', 'U') IS NULL
    CREATE TABLE User (
        id INT PRIMARY KEY IDENTITY(1,1),
        name NVARCHAR(255) NOT NULL,
        followers INT,
        rate FLOAT,
        url NVARCHAR(255) UNIQUE NOT NULL
    )
''')

cursor.execute('''
    IF OBJECT_ID('Shop', 'U') IS NULL
    CREATE TABLE Shop (
        id INT PRIMARY KEY IDENTITY(1,1),
        name NVARCHAR(255) NOT NULL,
        url NVARCHAR(255) UNIQUE NOT NULL
    )
''')

cursor.execute('''
    IF OBJECT_ID('Product', 'U') IS NULL
    CREATE TABLE Product (
        id INT PRIMARY KEY IDENTITY(1,1),
        name NVARCHAR(255) NOT NULL,
        rate FLOAT,
        id_shop INT,
        price FLOAT,
        detail NVARCHAR(MAX),
        url NVARCHAR(255) UNIQUE NOT NULL,
        CONSTRAINT FK_Product_Shop FOREIGN KEY (id_shop) REFERENCES Shop(id)
    )
''')

conn.commit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
driver = webdriver.Chrome(service=service)

# %% [markdown]
# # Scrape Data from Websites

# %% [markdown]
# ## Lazada website

# %%
url = 'https://www.lazada.vn/#?'
driver.get(url)
search_box = driver.find_element(By.CSS_SELECTOR, "input.search-box__input--O34g")
search_box.send_keys("Quần áo nữ")
search_button = driver.find_element(By.CSS_SELECTOR, "a.search-box__button--1oH7")
search_button.click()

product_urls = []
button_nextPage = driver.find_element(By.CSS_SELECTOR, 'li[title="Next Page"] button')

for i in range (0, 3):
    time.sleep(2)

    dr_products = driver.find_elements(By.CSS_SELECTOR, 'div[data-tracking="product-card"] a')
    print(len(dr_products))
    
    for product in dr_products:
        url = product.get_attribute('href')
        product_urls.append(url)
        print(url)
    
    product_urls = list(set(product_urls))
    button_nextPage.click()

# %%
print(len(product_urls))
for url in product_urls:
    print(url)

# %%
with open('Laz_product_urls.txt', mode='w') as file:
    for row in product_urls:
        file.write(row + "\n")

# %%
with open('Laz_product_urls.txt', mode='r') as file:
    links = file.readlines()
links = [link.strip() for link in links]
# print(links)

# %%
Laz_product_urls = links

# %%
Laz_shop_urls = []
for url in Laz_product_urls:
    driver.get(url)
    time.sleep(2)

    # input_quantity = driver.find_element(By.CSS_SELECTOR, 'div.next-number-picker-input-wrap input')
    if 
    if input_quantity.get_attribute('value') == '0':
        continue
        
    name = driver.find_element(By.CSS_SELECTOR, 'h1.pdp-mod-product-badge-title').text
    print(name)

    if driver.find_element(By.CSS_SELECTOR, 'span.pdp-price'):
        price = driver.find_element(By.CSS_SELECTOR, 'span.pdp-price').text
    else:
        price = 0
    print(price)

    if driver.find_element(By.CSS_SELECTOR, 'div.seller-link a'):
        shop_url = driver.find_element(By.CSS_SELECTOR, 'div.seller-link a').get_attribute('href')
        Laz_shop_urls.append(shop_url)
    else:
        shop_url = ''
    print(shop_url)

drive.quit()
# Out:
# Tangg mùa hè màu trơn cho nữ yếm trong bộ đồ ngủ có dây đeo Váy Ngủ Lụa băng nữ váy ngủ hai dây ngủ
# 51.900 ₫
# https://www.lazada.vn/shop/tangganshar/?itemId=2487901978&channelSource=pdp
# (XÉO NƠ THÊU có Bigsize) Bộ quần áo nữ Phật tử, đồ lam đi chùɑ mẫu nữ vải Kate mã KA06B
# 165.000 ₫
# https://www.lazada.vn/shop/hong-phuc-an/?itemId=2531297448&channelSource=pdp
# [HCM]ĐỒ BỘ NGỦ PHI BÓNG 2 DÂY PHỐI REN NGỰC LỤA THỔ CẨM NHIỀU MÀU THOẢI MÁIQUYẾN RŨ 06
# 33.000 ₫
# https://www.lazada.vn/shop/shopvan99/?itemId=440930617&channelSource=pdp
# bộ lửng tole lanh 2da (4 size) 40-80 kí
# 75.000 ₫
# https://www.lazada.vn/shop/heritageshop/?itemId=1000890667&channelSource=pdp
# (Combo 3q) Quần Legging Đùi Biker Short Body Dáng Ôm Boxer Ngắn Phong Cách Thể Thao Sporty Cá Tính Ulzang chất cotton
# 99.000 ₫
# https://www.lazada.vn/shop/xuong-may-song-anh/?itemId=2488730362&channelSource=pdp
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[47], line 6
#       3 driver.get(url)
#       4 time.sleep(2)
# ----> 6 input_quantity = driver.find_element(By.CSS_SELECTOR, 'div.next-number-picker-input-wrap input')
#       7 if input_quantity.get_attribute('value') == '0':
#       8     continue
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:748, in WebDriver.find_element(self, by, value)
#     745     by = By.CSS_SELECTOR
#     746     value = f'[name="{value}"]'
# --> 748 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":"div.next-number-picker-input-wrap input"}
#   (Session info: chrome=127.0.6533.120); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 	GetHandleVerifier [0x00508923+23283]
# 	(No symbol) [0x004CE934]
# 	(No symbol) [0x00400733]
# 	(No symbol) [0x0044326F]
# 	(No symbol) [0x004434AB]
# 	(No symbol) [0x0047EE42]
# 	(No symbol) [0x00464464]
# 	(No symbol) [0x0047CB8D]
# 	(No symbol) [0x004641B6]
# 	(No symbol) [0x00438017]
# 	(No symbol) [0x0043890D]
# 	GetHandleVerifier [0x005FA5F3+1013699]
# 	GetHandleVerifier [0x00603E4C+1052700]
# 	GetHandleVerifier [0x005FD4B4+1025668]
# 	GetHandleVerifier [0x0052EA2B+179195]
# 	(No symbol) [0x004D6833]
# 	(No symbol) [0x004D3198]
# 	(No symbol) [0x004D3337]
# 	(No symbol) [0x004CB4BE]
# 	BaseThreadInitThunk [0x76BE7D59+25]
# 	RtlInitializeExceptionChain [0x77B6B74B+107]
# 	RtlClearBits [0x77B6B6CF+191]

# %%
Laz_shop_urls = list(set(Laz_shop_urls))

# %%
len(Laz_shop_urls)
# Out:
# 70

# %%
# driver.get('https://www.lazada.vn/shop/an-store-chuyen-bo-me-va-be/?itemId=2635424282&channelSource=pdp')

for url in Laz_shop_urls:
    driver.get(url)
    time.sleep(2)
    
    name = driver.find_element(By.CSS_SELECTOR, '#pi-component-container > div > div:nth-child(2) > div > div > div > div:nth-child(2) > div:nth-child(1) > div > div > div > div:nth-child(2) > div:nth-child(1) > h1').text
    print(name)
    
    followers = driver.find_element(By.CSS_SELECTOR, '#pi-component-container > div > div:nth-child(2) > div > div > div > div:nth-child(2) > div:nth-child(1) > div > div > div > div:nth-child(2) > div:nth-child(2) > div').text
    print(followers)

# %% [markdown]
# ## Shein website

# %%
#The url below is the original link to homepage of Shein website
#url = 'https://www.shein.com.vn/?_gl=1*1gloy8n*_up*MQ..&gclid=EAIaIQobChMIgbqoh-mDiAMV9tIWBR3KgQ6KEAAYASAAEgKgHPD_BwE'

#This url is the Shein website after send key 'QUần áo nữ' to the search input 
url = 'https://www.shein.com.vn/pdsearch/Qu%E1%BA%A7n%20%C3%A1o%20n%E1%BB%AF/?ici=s1`EditSearch`Qu%E1%BA%A7n%20%C3%A1o%20n%E1%BB%AF`_fb`d0`PageSearchResult&search_source=1&search_type=all&source=search&src_identifier=st%3D2%60sc%3DQu%E1%BA%A7n%20%C3%A1o%20n%E1%BB%AF%60sr%3D0%60ps%3D1&src_identifier_pre_search=&src_module=search&src_tab_page_id=page_search1724166755052'
driver.get(url)
time.sleep(5)

product_urls = []

dr_products = driver.find_elements(By.CSS_SELECTOR, 'div.product-card__goods-title-container a.goods-title-link')
print(len(dr_products))

for product in dr_products:
    url = product.get_attribute('href')
    product_urls.append(url)
    print(url)

product_urls = list(set(product_urls))

# %%
with open('Shein_product_urls.txt', mode='w') as file:
    for row in product_urls:
        file.write(row + "\n")

# %%
with open('Shein_product_urls.txt', mode='r') as file:
    links = file.readlines()
links = [link.strip() for link in links]
# print(links)

# %%
Shein_product_urls = links

# %%
Shein_shop_urls = []
for url in Shein_product_urls:
    driver.get(url)
    time.sleep(2)
        
    name = driver.find_element(By.CSS_SELECTOR, 'h1.product-intro__head-name').text
    print(name)

    if driver.find_element(By.CSS_SELECTOR, 'div.ProductIntroHeadPrice__head-mainprice .original span'):
        price = driver.find_element(By.CSS_SELECTOR, 'div.ProductIntroHeadPrice__head-mainprice .original span').text
    else:
        price = 0
    print(price)

    # shop_content_box = driver.find_element(By. CSS_SELECTOR, '.shop-entry__contentBox').get_attribute('style')
    # if driver.find_element(By. CSS_SELECTOR, '.shop-entry__contentBox').get_attribute('display') == 'display: none;':
    #     driver.find_element(By.CSS_SELECTOR, '.product-intro__brand-head').click()
    #     time.sleep(2)
    #     shop_url = driver.find_element(By.CSS_SELECTOR, 'div.seller-link a').get_attribute('href')
    #     Shein_shop_urls.append(shop_url)
    # else:
    #     shop_url = ''
    # print(shop_url)

drive.quit()
# Out:
# DAZY Áo cami mùa hè màu trơn dành cho nữ
# 137.000₫
#
# SHEIN MOD Chất rắn Nếp gấp Phần Ngực Xù Hoa Sen Váy Dây Không có áo nịt ngực
# 194.900₫
#
# DAZY Áo thun nữ in hình nơ màu Slim Fit
# 133.000₫
#
# SHEIN BAE Áo khoác và áo lót dành cho xe tăng nữ Bất đối xứng Tương phản ren Chi tiết cốc màu trơn Thanh lịch
# 334.000₫
#
# MAALAVIDAA Nghệ Sĩ 1 Nữ Lưới In Hoa Trễ Vai Chặt Áo Dài Tay
# 181.600₫
#
# SHEIN ICON Áo quây không đối xứng in hình kỳ nghỉ hè Y2K Summer Tie-Dye Áo quây
# 86.000₫
#
# DAZY Của phụ nữ Không đối xứng Đường viền cổ áo Và Hem Tay áo dài Áo thun
# 167.000₫
#
#
#
#
#
#
#
# MUSERA Vi mô Váy mini
# 103.000₫
#
# ROMWE Kawaii Áo thun ren nhún ngực in họa tiết hoa nhỏ, đi học
# 193.000₫
#
# SHEIN MOD Đen Ngày Áo ngủ Câu lạc bộ NỮ Buộc lại Ren Mộc nhĩ Viền mặt trước Tay áo kèn Áo phông Crop
# 161.000₫
#
# ROMWE Fairycore Áo thun nữ Bất đối xứng Tương phản ren Khối Màu Họa tiết hoa Giải trí
# 165.000₫
#
# DAZY Quý cô Màu thuần Dây đeo Halter Neck Áo thun
# 160.000₫
#
# SHEIN x Marika Sila SHEIN MOD Mùa hè Đi ra ngoài Chất rắn Nơ ren Mặt trước Trắng Cami ngọn
# 117.000₫
#
# SHEIN ICON Cà vạt tay loe phía trước Rau diếp trang trí lưới trên cùng
# 95.000₫
#
# SHEIN EZwear Áo crop top in chữ khối màu Slim-Fit mùa hè
# 90.000₫
#
# SHEIN Coolane Quần dù thể thao Back To School cho nữ
# 341.000₫
#
# SHEIN Essnce Bộ áo ba lỗ không tay đơn giản màu trơn hàng ngày dành cho nữ
# 149.000₫
#
# SHEIN ICON Mùa hè dành cho nữ Họa tiết da báo Slim Fit Crop yếm thời trang Cami Top
# 110.000₫
#
# SHEIN BAE Quý cô Màu thuần Đơn giản Áo không dây
# 306.000₫
#
# SHEIN Privé Phong cách Trung Quốc mới Phong cách cổ điển Thẩm mỹ một nút thêu Áo cổ đứng lỏng lẻo
# 625.000₫
#
# SHEIN EZwear Quý cô Màu thuần Xếp li Halterneck Áo ba lỗ
# 106.000₫
#
# ROMWE Váy nữ màu trơn Giải trí
# 162.000₫
#
# SHEIN Privé Quý cô Màu thuần Hình vuông Đường viền cổ áo Xếp li Váy bodycon
# 152.000₫
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# SHEIN EZwear Áo thun nữ ngắn tay cổ tròn in hình gấu trắng giản dị phong cách đại học California, thích hợp cho mùa hè, LOS ANGELES CALIFORNIA CẢNH QUAN ĐẸP NHẤT LÀ TRONG CHUYẾN ĐI LÀM NHỮNG GÌ BẠN MUỐN LÀM
# 130.500₫
#
# SHEIN MOD Của phụ nữ Ren Cắt tỉa Xếp li Áo
# 208.000₫
#
# SHEIN MOD Nhuộm buộc cổ áo xếp nếp Viền ven Buộc lại Áo hai dây , In Ombre , In Đá cẩm thạch
# 92.000₫
#
# Nữ Punk Cổ Tròn Tay Ngắn Môi In Hình Thời Trang Gothic Dạo Phố Áo Thun
# 135.000₫
#
# SHEIN EZwear Bộ 4 áo thun ngắn tay trơn đơn giản dành cho nữ, thích hợp cho mùa hè
# 221.000₫
#
# FRIFUL Áo sơ mi sọc dài tay cổ chữ V dáng rộng thời trang dành cho nữ
# 289.000₫
#
# DAZY Sọc Áo thun Thả vai
# 208.000₫
#
# SHEIN MOD Quý cô Ruffled Váy kiểu Băng đô
# 178.000₫
#
# Áo thun ngắn tay in slogan giản dị dành cho nữ, mùa hè
# 180.200₫
#
# DAZY Áo kiểu nữ Jacquard dáng rộng thanh lịch mùa thu mới xuất hiện
# 307.700₫
#
# SHEIN EZwear Quần nữ Túi màu trơn Giải trí
# 189.000₫
#
# SHEIN EZwear Quý cô Ngắn tay Áo thun Với In thư
# 123.000₫
#
# SHEIN EZwear Váy kẻ sọc in xà lách viền váy nàng tiên cá
# 139.000₫
#
# Áo thun dáng rộng in họa tiết cổ điển thường ngày mùa hè cho nữ
# 179.500₫
#
# SHEIN ICON Quý cô Màu thuần Ngắn Top Cây trồng Và Ngắn Khăn choàng
# 98.000₫
#
# SHEIN EZwear Quý cô 2 Miếng Chất rắn Xù Bustier Áo ba lỗ
# 156.000₫
#
# SHEIN EZwear Đầm Mini Cami Bodycon Phối Ren Gợi Cảm Cho Nữ
# 137.000₫
#
# SHEIN ICON Ren Mộc nhĩ Bên dây rút Viền không đối xứng Lưới Ống Bất đối xứng Áo
# 76.600₫
#
# SHEIN WYWH Mùa hè Đi ra ngoài Lỗ gắn thêu Ca-vát Backless Viền khăn tay Nếp gấp Dây Trắng Áo
# 73.600₫
#
# SHEIN ICON Bộ áo hai dây không tay dành cho nữ với váy
# 186.000₫
#
# SHEIN EZwear Mùa hè in họa tiết kẻ sọc phía trước ống viền bất đối xứng màu xanh lá cây
# 83.000₫
#
# SHEIN Essnce Của phụ nữ Màu thuần Thon gọn Áo thun
# 88.000₫
#
# SHEIN EZwear Áo dây xếp nếp màu trơn mùa hè
# 131.000₫
#
# SHEIN MOD Cà chua Cô Gái Mùa Hè Coquette Nơ Tay Phồng Áo Sơ Mi Nữ Slim Fit Có Viền Tương Phản
# 192.000₫
#
# SHEIN Maija Áo cổ lọ trang trí bằng kim cương giả thường ngày xuân hè dành cho nữ
# 334.000₫
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 4
#       2 for url in Shein_product_urls:
#       3     driver.get(url)
# ----> 4     time.sleep(2)
#       6     name = driver.find_element(By.CSS_SELECTOR, 'h1.product-intro__head-name').text
#       7     print(name)
#
# KeyboardInterrupt:

# %% [markdown]
# ## Tiki website

# %%
#The url below is the original link to homepage of Tiki website
#url = 'https://tiki.vn/'

#This url is the Tiki website after send key 'QUần áo nữ' to the search input 
url = 'https://tiki.vn/search?q=Qu%E1%BA%A7n%20%C3%A1o%20n%E1%BB%AF'
driver.get(url)
time.sleep(5)

product_urls = []
button_nextPage = driver.find_element(By.CSS_SELECTOR, '.pagination-block div:nth-child(3) a')
dr_products = driver.find_elements(By.CSS_SELECTOR, 'a[data-view-id="product_list_item"]')
print(len(dr_products))

for i in range (0, 3):
    time.sleep(2)

    dr_products = driver.find_elements(By.CSS_SELECTOR, 'a[data-view-id="product_list_item"]')
    print(len(dr_products))
    
    for product in dr_products:
        url = product.get_attribute('href')
        product_urls.append(url)
        print(url)
    
    product_urls = list(set(product_urls))
    button_nextPage.click()
# Out:
# 40
# 40
# https://tiki.vn/set-do-bo-nu-quan-caro-phoi-ao-co-tim-thun-cotton-mat-min-p64636058.html?spid=64636084
# https://tiki.vn/set-do-nu-chat-dui-bo-do-nu-he-ao-yem-quan-dui-chat-dui-xinh-xa-n-p117573855.html?spid=117573861
# https://tiki.vn/set-do-bo-nu-quan-da-beo-phoi-ao-mau-nang-dong-p66580038.html?spid=66580056
# https://tiki.vn/do-bo-nu-quan-ong-suong-ao-so-mi-2-tui-sang-trong-p177272170.html?spid=177272175
# https://tiki.vn/set-bo-quan-ao-nam-nu-in-gau-erubrold-chat-vai-cotton-mem-mat-sieu-cute-wedo-p176416494.html?spid=176416538
# https://tiki.vn/set-bo-dui-mac-nha-danh-cho-nu-do-bo-thun-cotton-mac-nha-duihoa-p196898280.html?spid=271118577
# https://tiki.vn/ao-tre-vai-phom-dai-rong-mac-giau-quan_ao-ho-vai-phom-rong-p221712488.html?spid=221712544
# https://tiki.vn/set-bo-quan-short-kaki-ao-thun-hit-hot-vn01-p54344899.html?spid=56844402
# https://tiki.vn/bo-so-mi-nu-trang-form-rong-va-quan-dui-tre-trung-thoi-trang-mua-xuan-he-cho-nu-dui-viet-p271940039.html?spid=271940142
# https://tiki.vn/quan-ao-do-bo-nu-xinh-chat-kate-p207363263.html?spid=207363292
# https://tiki.vn/set-bo-quan-tui-hop-cotton-lanh-ao-thun-tam-gan-mau-y-hinh-p270702215.html?spid=270702217
# https://tiki.vn/jum-nu-dinh-kim-tuyen-cot-no-thoi-trang-p76201236.html?spid=76201242

# %%
with open('Tiki_product_urls.txt', mode='w') as file:
    for row in product_urls:
        file.write(row + "\n")

# %%
with open('Tiki_product_urls.txt', mode='r') as file:
    links = file.readlines()
links = [link.strip() for link in links]
# print(links)

# %%
Tiki_product_urls = links

# %%
Tiki_shop_urls = []
for url in Tiki_product_urls:
    driver.get(url)
    time.sleep(2)
        
    name = driver.find_element(By.CSS_SELECTOR, 'h1.Title__TitledStyled-sc-c64ni5-0').text
    print(name)

    if driver.find_element(By.CSS_SELECTOR, '.product-price__current-price'):
        price = driver.find_element(By.CSS_SELECTOR, '.product-price__current-price').text
    else:
        price = 0
    print(price)
    
    if driver.find_element(By.CSS_SELECTOR, 'a[data-view-id="pdp_details_view_brand"]'):
        shop_url = driver.find_element(By.CSS_SELECTOR, 'a[data-view-id="pdp_details_view_brand"]').get_attribute('href')
        Tiki_shop_urls.append(shop_url)
    else:
        shop_url = ''
    print(shop_url)

drive.quit()
# Out:
# Sét Đồ Bộ Nữ Thời Trang
# 143.100₫
# https://tiki.vn/thuong-hieu/oem.html
# set đồ nữ, bộ quần áo nữ thu đông áo dài tay, quần short 2 màu nâu, đen in chữ phong cách cá tính
# 99.000₫
# https://tiki.vn/thuong-hieu/oem.html
# Set bộ đồ nữ 3 món với tone màu hồng đơn giản xinh xắn, Sét sơ mi 3 món đi biển, áo sơ mi + quần đùi chất cotton kèm áo,
# 175.000₫
# https://tiki.vn/thuong-hieu/jinrinteen.html
# Jumpsui Ngắn Nữ Tính Kiểu Jumpsuit Cổ Đắp Chéo Phối Phụ Kiện GOTI 3182
# 228.000₫
# https://tiki.vn/thuong-hieu/goti.html
# Sét Bộ Nữ Công Sở LUPERI LFSB499 Áo Cộc Tay Phối Đai Kết Hợp Quần Dài
# 1.050.000₫
# https://tiki.vn/thuong-hieu/luperi.html
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 4
#       2 for url in Tiki_product_urls:
#       3     driver.get(url)
# ----> 4     time.sleep(2)
#       6     name = driver.find_element(By.CSS_SELECTOR, 'h1.Title__TitledStyled-sc-c64ni5-0').text
#       7     print(name)
#
# KeyboardInterrupt:
